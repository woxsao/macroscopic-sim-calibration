# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
ten_min_flow_speed_data = pd.read_csv("data/10sec_100_m_flow_speed_1hr.csv")
print(ten_min_flow_speed_data)
# Out:
#                                 Time          Space    Flow      Speed
# 0      2022-11-30 13:00:00.400000095   94376.195312   301.0  85.475494
# 1      2022-11-30 13:00:00.400000095   94476.195312   666.0  82.841446
# 2      2022-11-30 13:00:00.400000095   94576.195312   956.0  77.933006
# 3      2022-11-30 13:00:00.400000095   94676.195312   752.0  77.137398
# 4      2022-11-30 13:00:00.400000095   94776.195312   401.0  74.909111
# ...                              ...            ...     ...        ...
# 24475  2022-11-30 13:59:50.400000095  100676.195312   922.0  21.755562
# 24476  2022-11-30 13:59:50.400000095  100776.195312  1593.0  21.698355
# 24477  2022-11-30 13:59:50.400000095  100876.195312   403.0  43.288197
# 24478  2022-11-30 13:59:50.400000095  100976.195312   619.0  51.534195
# 24479  2022-11-30 13:59:50.400000095  101076.195312     0.0   0.000000
#
# [24480 rows x 4 columns]

# %%
flow = ten_min_flow_speed_data["Flow"]
speed = ten_min_flow_speed_data["Speed"]
ten_min_flow_speed_data["Density"] = flow/speed
print(ten_min_flow_speed_data["Space"].iloc[100])
first_space_value = ten_min_flow_speed_data['Space'].iloc[100]
print(first_space_value)

filtered_data = ten_min_flow_speed_data[ten_min_flow_speed_data["Space"] == first_space_value]
print(filtered_data)
plt.figure(figsize=(8, 6))
plt.scatter(filtered_data['Density'], filtered_data['Flow'], c='blue', alpha=0.6)
plt.xlim(0, 300)
plt.title('Density-Flow Diagram')
plt.xlabel('Density (vehicles per distance unit)')
plt.ylabel('Flow (vehicles per time unit)')
plt.grid(True)
plt.show()
# Out:
# 97576.1953125
# 97576.1953125
#                                 Time         Space    Flow      Speed  \
# 32     2022-11-30 13:00:00.400000095  97576.195312   969.0  31.168156
# 100    2022-11-30 13:00:10.400000095  97576.195312  1361.0  30.177168
# 168    2022-11-30 13:00:20.400000095  97576.195312  1906.0  32.565334
# 236    2022-11-30 13:00:30.400000095  97576.195312  1964.0  29.657324
# 304    2022-11-30 13:00:40.400000095  97576.195312  2232.0  24.720236
# ...                              ...           ...     ...        ...
# 24172  2022-11-30 13:59:10.400000095  97576.195312  1671.0  36.206398
# 24240  2022-11-30 13:59:20.400000095  97576.195312  1558.0  44.504845
# 24308  2022-11-30 13:59:30.400000095  97576.195312  1326.0  49.014950
# 24376  2022-11-30 13:59:40.400000095  97576.195312   927.0  52.201019
# 24444  2022-11-30 13:59:50.400000095  97576.195312   314.0  54.262951
#
#          Density
# 32     31.089424
# 100    45.100322
# 168    58.528495
# 236    66.223103
# ...
